# %% [markdown]
# #### Implementation of the bivariate - having two variables/columns and multivariate having more than two variables
# #### Author: Zaryab Hussain

# %%
import pandas as pd         # for read the dataset

# %%
import seaborn as sns       # for graphs and visualization

# %% [markdown]
# ##### Loading the Datset

# %%
df = pd.read_csv("Flipkart_Mobile_Dataset.csv")

# %%
df
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %%
df.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5        11990.0
#
#    Original Price
# 0         15990.0
# 1         15990.0
# 2         17990.0
# 3         17990.0
# 4         15990.0

# %%
df.tail()
# Out:
#        Brand      Model         Color Memory Storage  Rating  Selling Price  \
# 2642  Xiaomi  Redmi Y3       Bold Red   4 GB   64 GB     4.3        12999.0
# 2643  Xiaomi  Redmi Y3   Elegant Blue   3 GB   32 GB     4.3         9450.0
# 2644  Xiaomi  Redmi Y3   Elegant Blue   4 GB   64 GB     4.2        12999.0
# 2645  Xiaomi  Redmi Y3    Prime Black   3 GB   32 GB     4.2         9950.0
# 2646  Xiaomi  Redmi Y3    Prime Black   4 GB   64 GB     4.3        12499.0
#
#       Original Price
# 2642         13999.0
# 2643             NaN
# 2644             NaN
# 2645             NaN
# 2646         13999.0

# %%
df.describe()
# Out:
#             Rating  Selling Price  Original Price
# count  2647.000000    2644.000000      969.000000
# mean      4.001700   26461.362330    29852.605779
# std       0.997499   29833.135164    27659.141051
# min       0.000000    1000.000000     1599.000000
# 25%       4.000000    9490.000000    12999.000000
# 50%       4.300000   14999.000000    18999.000000
# 75%       4.400000   29998.250000    34999.000000
# max       5.000000  179900.000000   189999.000000

# %% [markdown]
# #### 1. Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(x=df['Selling Price'],y=df['Rating'])   # for bivariate, price_deatils and tip stars
# Out:
# <Axes: xlabel='Selling Price', ylabel='Rating'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
sns.countplot(df, x= "Brand")        # plot the brand name of mobile phones 
plt.xticks(rotation=45, ha="right")
plt.show()
pd.value_counts(df['Brand'])         # determine the numerical value of the name
# Out:
# C:\Users\Zaryab\AppData\Local\Temp\ipykernel_11000\2897329942.py:6: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df['Brand'])         # determine the numerical value of the name
# Brand
# SAMSUNG         695
# Apple           364
# realme          285
# OPPO            244
# Nokia           212
# Xiaomi          164
# GIONEE          129
# Lenovo          121
# ASUS            113
# Motorola        105
# LG               99
# vivo             57
# Google Pixel     29
# POCO             20
# HTC               5
# IQOO              5
# Name: count, dtype: int64

# %%
# for multivariate - Selling Price, Rating and Brand, hue is used here

sns.scatterplot(x=df['Selling Price'],y=df['Rating'],hue=df['Brand'])

# The following scatter plot helps us understand how price and ratings are distributed across various brands
# Out:
# <Axes: xlabel='Selling Price', ylabel='Rating'>

# %% [markdown]
# ### 2. Bar Plot (Numerical - Categorical)

# %%
# what is average price of a mobile phone
# x-axis = categorical and y-axis = numerical


plt.figure(figsize=(12, 6))
sns.barplot(x=df['Brand'], y=df['Selling Price'])
plt.xticks(rotation=45, ha="right")
plt.title('Selling Price by Brand')
plt.show()

# %% [markdown]
# ### 3. Box Plot (Numerical - Categorical)

# %%
# boxplot is usually used to identify the outliers
plt.figure(figsize=(12, 6))

# Create the boxplot for 'Brand' vs 'Rating'
sns.boxplot(x='Brand', y='Rating', data=df)
plt.xticks(rotation=45, ha="right")
plt.title('Boxplot of Ratings by Brand')
plt.show()

# %%
# Boxplot: Impact of Brand and Memory on Selling Price

plt.figure(figsize=(12, 6))
sns.boxplot(x='Brand', y='Selling Price', hue='Memory', data=df)
plt.xticks(rotation=45, ha='right')
plt.title('Selling Price of Mobiles by Brand and Memory Size')
plt.show()

# %% [markdown]
# ### 4. Distplot (Numerical - Categorical)

# %%
# Creatinging a binary column for ratings
df['High Rating'] = df['Rating'].apply(lambda x: 1 if x > 4 else 0)

# %%
plt.figure(figsize=(12, 6))

# low ratings
sns.kdeplot(df[df['High Rating'] == 0]['Rating'], label='Low Rating (<= 4)', color='blue', fill=False)

# high ratings
sns.kdeplot(df[df['High Rating'] == 1]['Rating'], label='High Rating (> 4)', color='orange', fill=False)

plt.title('Distribution of Ratings by High and Low Ratings')
plt.xlabel('Rating')
plt.ylabel('Density')
plt.legend()

plt.show()

# %% [markdown]
# ### 5. HeatMap (Categorical - Categorical)

# %%
# Creating a binary column for high ratings
df['High Rating'] = df['Rating'].apply(lambda x: 1 if x > 4 else 0)

# %%
rating_crosstab = pd.crosstab(df['Brand'], df['High Rating'], rownames=['Brand'], colnames=['High Rating'])
print(rating_crosstab)

# 1 indicates a rating greater than 4 and 0 indicates 4 or less
# Out:
# High Rating     0    1
# Brand
# ASUS           53   60
# Apple          53  311
# GIONEE         97   32
# Google Pixel    0   29
# HTC             4    1
# IQOO            0    5
# LG             63   36
# Lenovo         69   52
# Motorola       22   83
# Nokia         130   82
# OPPO           20  224
# POCO            0   20
# SAMSUNG       141  554
# Xiaomi         10  154
# realme         32  253
# vivo            4   53

# %%
df['High Rating'] = df['Rating'].apply(lambda x: 1 if x > 4 else 0)

# %%
crosstab = pd.crosstab(df['Brand'], df['High Rating'])

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(crosstab, annot=True, cmap='YlGnBu', fmt='g')
plt.title('Heatmap')
plt.xlabel('High Rating (1 = > 4, 0 = <= 4)')
plt.ylabel('Brand')

plt.show()

# %%
# the percentage or numbers of the above graph or Rating of each mobile brand in percentage
max_rating = 5

percentage_ratings = (df.groupby('Brand')['Rating'].mean() / max_rating) * 100

print(percentage_ratings)
# Out:
# Brand
# ASUS            80.212389
# Apple           77.950549
# GIONEE          75.829457
# Google Pixel    90.137931
# HTC             81.200000
# IQOO            88.000000
# LG              78.828283
# Lenovo          78.842975
# Motorola        81.276190
# Nokia           70.547170
# OPPO            83.803279
# POCO            86.200000
# SAMSUNG         82.837410
# Xiaomi          83.012195
# realme          77.866667
# vivo            83.964912
# Name: Rating, dtype: float64

# %%
(df.groupby('Brand')['Rating'].mean() * 100).plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %% [markdown]
# ### 6. ClusterMap (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(df['Brand'],df['Rating']))

# %% [markdown]
# ### 7. Pairplot - Collection of scatter

# %%
sns.pairplot(df,hue='Brand')
# Visualizing the relationships between numerical variables in the mobile dataset,
# colored by Brand to observe how different brands distribute across features

# %%
sns.pairplot(df,hue='Storage')
# Exploring the pairwise relationships in the dataset with different colors 
# representing Storage capacity, allowing for analysis of how storage affects other numerical features

# %% [markdown]
# ### 8. Lineplot (Numerical - Numerical)

# %%
sns.lineplot(x=df['Selling Price'],y=df['Original Price'])
# how selling price relates to original price
# Out:
# <Axes: xlabel='Selling Price', ylabel='Original Price'>

# %%
sns.regplot(x='Selling Price', y='Original Price', data=df)
# how selling price relates to original price using regression line
# Out:
# <Axes: xlabel='Selling Price', ylabel='Original Price'>
